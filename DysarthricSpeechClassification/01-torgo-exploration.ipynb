# %%
# 01-torgo-exploration

# Author: Eryk Urbański
# Date: May 2025
# Description: TORGO Dataset Exploration

# %%
import matplotlib.pyplot as plt
import numpy as np
import soundfile as sf

# %% [markdown]
# # Load dataset

# %%
from dataset_loader import TORGO

# %%
torgo_path = "E:\\STUDIA\\semestr 8\\WSI\\Projekt\\Data\\TORGO" # Adjust as needed
torgo = TORGO(path=torgo_path)
# Out:
# Initialized TORGO dataset with 17635 files.

# %% [markdown]
# # Visualise example waveforms

# %%
torgo.show(1)
torgo.show(5000)

# %% [markdown]
# # Unevennes of audio lengths

# %%
audio1_path, label1 = torgo[1]
audio1, _ = sf.read(audio1_path)
audio5000_path, label5000 = torgo[5000]
audio5000, _ = sf.read(audio5000_path)
audio13000_path, label13000 = torgo[13000]
audio13000, _ = sf.read(audio13000_path)
audio17000_path, label17000 = torgo[17000]
audio17000, _ = sf.read(audio17000_path)
audio1.shape, label1, audio5000.shape, label5000, audio13000.shape, label13000, audio17000.shape, label17000
# Out:
# ((117600,), 0, (31200,), 1, (28587,), 0, (125760,), 1)

# %% [markdown]
# # Class distribution

# %%
labels = torgo.labels

# Get class distribution
classes, counts = np.unique(labels, return_counts=True)

# Optional: map labels to human-readable names
label_names = ['Non-Dysarthric', 'Dysarthric']  # assuming 0 = Control, 1 = Dysarthric

# Custom function to show both percentage and count
def autopct_format(pct, allvals):
    absolute = int(np.round(pct / 100. * np.sum(allvals)))
    return f"{pct:.1f}%\n({absolute})"

# Plot pie chart
plt.figure(figsize=(6, 6))
plt.pie(
    counts,
    labels=label_names,
    autopct=lambda pct: autopct_format(pct, counts),
    startangle=90,
    colors=['skyblue', 'salmon']
)
plt.title('TORGO Dataset Class Distribution')
plt.axis('equal')  # Ensures the pie chart is circular
plt.show()
